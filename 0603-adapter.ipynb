# %% [markdown]
# # Nvidia Nemotron Outside Submission
# This notebook is for submitting only (I trained several version on different notebooks and I share that model here)
# Default config (if there are any changes, I will mention in every cell's markdown):
# * LoRA rank = 32
# * LoRA alpha = 32
# * Drop out = 0.05
# * Grad accumulation = 4
# * LR = 2e-4
# * epochs = 2
# * Seq length = 2048
# * Batch size = 1
# ---

# %% [markdown]
# ## VERSION 1
# * 600 samples
# * packing = False
# * LoRA rank = 16 → memory-efficient
# * target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]
# ---

# %% [markdown]
# ## VERSION 2
# * 1800 samples
# * packing = False
# * Batch size = 2
# * target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]
# ---

# %% [markdown]
# ## VERSION 3
# * 2400 samples
# * packing = False
# * Batch size = 2
# * target_modules="all-linear"
# * LR=1e-4
# ---

# %% [markdown]
# ## VERSION 4
# * 9500 samples
# * packing = False
# * Epoch = 1
# * Batch size = 1
# * target_modules=["in_proj", "x_proj", "dt_proj", "out_proj"]
# * LR=1e-4
# ---

# %% [markdown]
# ## VERSION 5
# * 3000 samples
# * packing = False
# * Epoch = 2
# * Batch size = 1
# * target_modules="all-linear"
# * LR=1e-4
# ---

# %% [markdown]
# ## VERSION 6
# * 1200 samples
# * packing = False
# * Epoch = 2
# * Batch size = 1
# * target_modules="all-linear"
# * LR=5e-5
# ---

# %% [markdown]
# ## VERSION 7
# * 1200 samples
# * packing = False
# * Epoch = 2
# * Batch size = 1
# * target_modules="all-linear"
# * LR=1e-4
# ---

# %% [markdown]
# ## VERSION 8
# * 1200 samples
# * packing = False
# * Epoch = 2
# * Batch size = 1
# * target_modules="all-linear"
# * LR=1e-5
# ---

# %% [markdown]
# ## VERSION 9
# ### Using this notebook (but modify its params):
# https://www.kaggle.com/code/konbu17/nemotron-sft-lora-with-cot-v2-prep-now-plz-wait
#
# * lr=1e-5
# ---

# %% [markdown]
# ## VERSION 10
# ### Using this notebook (but modify its params):
# https://www.kaggle.com/code/konbu17/nemotron-sft-lora-with-cot-v2-prep-now-plz-wait
#
# * lr=5e-5
# ---

# %% [markdown]
# ## VERSION 11
# ### Using this notebook (but modify its params):
# https://www.kaggle.com/code/konbu17/nemotron-sft-lora-with-cot-v2-prep-now-plz-wait
#
# * lr=1e-5
# * batch_size=2
# * workers=8
# ---

# %% [markdown]
# ## VERSION 12
# ### Using this notebook (but modify its params):
#
# https://www.kaggle.com/code/kienngx/nemotron-sft-reasoning-trajectories-dataset?scriptVersionId=309867482
#
#
# * lr=1e-5
# * batch_size=2
# * workers=8
# ---

# %% [markdown]
# ## VERSION 13
# ### Using this notebook:
#
# https://www.kaggle.com/code/impooping/nemotron-sft-reasoning-trajectories-dataset/notebook#Mode-A:-Train-on-Kaggle
#
# * lr=1e-5
# * batch_size=2
# * workers=8
# * grad_accum=16
#
# #### ~4h training 94GB/96GB VRAM
#
# ---

# %% [markdown]
# ## VERSION 14
#
# ### Using this notebook:
#
# https://www.kaggle.com/code/asalhi/tinker-adapter-to-ready-to-submit-adapter?scriptVersionId=311706799
#
# ---

# %%
import zipfile
import os

zip_path = "/kaggle/input/notebooks/mirzayasirabdullah07/nvidia-nemotron-model-reasoning-notebook/submission.zip"
extract_to = "/kaggle/working/submission_extracted/"

os.makedirs(extract_to, exist_ok=True)
with zipfile.ZipFile(zip_path, 'r') as zf:
    zf.extractall(extract_to)
    print(zf.namelist())
# Out:
# ['adapter_config.json', 'adapter_model.safetensors']

# %%
import os

version_1 =  "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/transformers/600-samples-packing-false/1"

version_2 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/transformers/1800s-lora-rank32-false/1"

version_3 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/transformers/2400-1e-4_lr-all_linear-packingfalse/1"

version_4 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/transformers/9500s-batch1-lr1e-4/1"

version_5 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/transformers/cot-labels-3000samples/1"

version_6 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/transformers/1200samples-cot-5e-5/1"

version_7 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/transformers/1200samples-cot-/1"

version_8 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/transformers/1200samples-cot-1e-5/1"

version_9 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/triton/1e-5/1"

version_10 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/triton/5e-5/1"

version_11 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/triton/1e-5-batch-2-workers-8/1"

version_12 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/triton/batch2-lr1e-workers8/1"

version_13 = "/kaggle/input/models/kienngx/nemotron-nano-30b-trained/triton/grad-accum1-workers8-maxlen-4096-lr1e-5/1"

version_14 = "/kaggle/working/submission_extracted"

model_path = version_14

# Zip it
zip_name = "submission.zip"
os.system(f'zip -r {zip_name} "{model_path}"')
# Out:
#   adding: kaggle/working/submission_extracted/ (stored 0%)
#   adding: kaggle/working/submission_extracted/adapter_model.safetensors (deflated 10%)
#   adding: kaggle/working/submission_extracted/adapter_config.json (deflated 58%)
# 0
